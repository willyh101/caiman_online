# %%
from glob import glob
import matplotlib.pyplot as plt
import numpy as np

from caiman_main import SimulateAcq
from utils import tic, toc, ptoc, remove_artifacts, mm3d_to_img
# Out:
# C:\Users\Res_Imaging\Anaconda3\envs\caiman\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Res_Imaging\Anaconda3\envs\caiman\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Res_Imaging\Anaconda3\envs\caiman\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Res_Imaging\Anaconda3\envs\caiman\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Res_Imaging\Anaconda3\envs\caiman\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Res_Imaging\Anaconda3\envs\caiman\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# # make a structural image
# # can do however you want, just needs to be an image that matches the X dims in image_params (100,400)

# mm3d_file = glob('E:/caiman_scratch/template/*.mat')[0]
# mm3d_img = mm3d_to_img(mm3d_file, chan=0)

# # below should work on any image
# structural_image = remove_artifacts(mm3d_img, 100, 400)
# structural_image = structural_image[0,:,:] # select for only top plane in image

# plt.imshow(structural_image)

# %%
from glob import glob 
import imageio
import cv2

user_name = 'Mora'
x_start = 50
x_end = 450
date = '20200718'
mouse = 'MBOT5_419'
exp_name = 'oriPostStim'



tif_folder = 'D://'+ user_name + '//' + date +'//' + mouse + '//' + exp_name + '//'
reference_folder ='D://' + user_name +'//'+ date +'//'+ mouse +'//'+ 'reference' + '//'
image_path = glob(reference_folder + '*.png')[0]


mR= imageio.imread(image_path)
image = mR[:,x_start:x_end,0]
cv2.imwrite(reference_folder + 'caiman_template.png',image)
plt.imshow(image)
# Out:
# True

# %%
print(reference_folder + '*.png')

# %%
dxy = (2., 2.) # spatial resolution in x and y in (um per pixel)
max_shift_um = (12., 12.) # maximum shift in um
patch_motion_xy = (25., 25.) # patch size for non-rigid correction in um

image_params = {
    'channels': 2,
    'planes': 1,
    'x_start': x_start,
    'x_end': x_end,
    'folder': tif_folder, # this is where the tiffs are
    'chunk_size': 40, # number of tiffs to do at once
    'structural_img': image
}

caiman_params = {
    'fr': 15,  # imaging rate in frames per second, per plane
    'overlaps': (24, 24),
    'max_deviation_rigid': 3,
    'p': 2,  # deconv 0 is off, 1 is slow, 2 is fast
    'nb': 3,  # background compenents -> nb: 3 for complex
    'decay_time': 1.0,  # sensor tau
    'gSig': (7, 7),  # expected half size of neurons in pixels, very important for proper component detection
    'only_init': False,  # has to be `False` when seeded CNMF is used
    'rf': None,  # half-size of the patches in pixels. Should be `None` when seeded CNMF is used.
    'pw_rigid': True,  # piece-wise rigid flag
    'ssub': 1,
    'tsub': 1,
    'merge_thr': 0.99,
    'num_frames_split': 20,
    'border_nan': 'copy',
    'max_shifts': [int(a/b) for a, b in zip(max_shift_um, dxy)],
    'strides': tuple([int(a/b) for a, b in zip(patch_motion_xy, dxy)])
}

# %%
tif_folder

# %%
expt = SimulateAcq(caiman_params, **image_params)
expt.run_fake_expt()
# Out:
# Starting segmentation on a provided template...
# done in 2.7476 s
# Setting up caiman...
# Starting local cluster... done.
# Nothing to remove!
# Nothing to remove!
# Nothing to remove!
# Memory mapping current file... done. Took 125.7324s
# Starting motion correction and CNMF...
# spatial support for each components given by the user
# CNMF fitting done. Took 178.9774s
# Memory mapping current file... done. Took 157.1160s
# Starting motion correction and CNMF...
# spatial support for each components given by the user
# CNMF fitting done. Took 113.7006s
# Memory mapping current file... done. Took 156.5851s
# Starting motion correction and CNMF...
# spatial support for each components given by the user
# CNMF fitting done. Took 112.3236s
# Memory mapping current file... done. Took 157.9580s
# Starting motion correction and CNMF...
# spatial support for each components given by the user
# CNMF fitting done. Took 109.1658s
# Memory mapping current file... done. Took 47.2995s
# Starting motion correction and CNMF...
# spatial support for each components given by the user
# CNMF fitting done. Took 94.9713s
# processing files: ['F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00001.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00002.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00003.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00004.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00005.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00006.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00007.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00008.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00009.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00010.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00011.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00012.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00013.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00014.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00015.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00016.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00017.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00018.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00019.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00020.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00021.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00022.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00023.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00024.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00025.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00026.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00027.tif', 'F://Experiments//EMX-Cre_CaMK2-tTA_tetO-GCaMP_Chrome virus//20200316//MBOC5_399//20200316//ori\\reti_399_920nm_power50_zoom1_z75_00028.tif', 'F:// ...
# spatial support for each components given by the user
# CNMF fitting done. Took 5262.2315s
# Caiman online analysis done.

# %%
1
# Out:
# 1

# %%
1
# Out:
# 1

# %%
1
# Out:
# 1
